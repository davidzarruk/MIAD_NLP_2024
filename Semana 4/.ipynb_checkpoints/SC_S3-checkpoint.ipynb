# %% [markdown]
# # INEGI:

# %%
import requests
import pandas as pd

url = "https://inegi.org.mx/app/tabulados/serviciocuadros/wsDataService.svc/listaindicador/669026/false/0700/es/json/2020/2024"
response = requests.get(url)

# %%
response.json()[0]['Data'][0]['Serie']['Obs'][1]['CurrentValue']
# Out:
# '100.327453557477'

# %%
if response.status_code == 200:
    data = response.json()[0]['Data']
    metadata = data[0]['MetaData']
    obs = data[0]['Serie']['Obs']
    df = pd.DataFrame(obs)
    df['Unit'] = metadata['Unit']
    df['Indicador'] = metadata['Indicador']
    df['Name'] = metadata['Name']
    df['Freq'] = metadata['Freq']
    print(df)
else:
    print("Error while retrieving data")
# Out:
#         CurrentValue TimePeriod ValueNoNumeric ValueStatus  \
# 0   99.8713989880644    2020/01
# 1   100.327453557477    2020/02
# 2   102.659576415878    2020/03
# 3   104.668949614233    2020/04
# 4   104.141031040515    2020/05
# 5   103.494822641698    2020/06
# 6   104.481839333954    2020/07
# 7   104.854011747303    2020/08
# 8   104.483432542836    2020/09
# 9   104.544548056715    2020/10
# 10  104.286063610244    2020/11
# 11  104.293330453388    2020/12
# 12  105.117889550116    2021/01
# 13  106.227089169911    2021/02
# 14  107.615671628274    2021/03
# 15  107.975562356445    2021/04
# 16  108.758794456484    2021/05
# 17   109.53367544218    2021/06
# 18  110.016963327811    2021/07
# 19  110.401996618312    2021/08
# 20  110.771040047483    2021/09
# 21  111.929447011904    2021/10
# 22  112.996538162885    2021/11
# 23  113.996785659154    2021/12
# 24  114.319491741409    2022/01
# 25  115.466391369003    2022/02
# 26  116.859841207251    2022/03
# 27  117.654293140319    2022/04
# 28  118.488796579428    2022/05
# 29  119.315341923893    2022/06
# 30   119.98965218176    2022/07
# 31  120.118906827831    2022/08
# 32  120.047471154775    2022/09
# 33  119.872171521833    2022/10
# 34  119.669616003589    2022/11
# 35  120.061750830955    2022/12
# 36  120.773962730101    2023/01
# 37  120.819125913685    2023/02
# 38  121.262395906002    2023/03
# 39  121.246624157013    2023/04
# 40  120.961546759032    2023/05
# 41  120.660241525637    2023/06
# 42  120.840632624466    2023/07
# 43  121.196044236233    2023/08
# 44  121.340790909199    2023/09
# 45  121.780187154914    2023/10
# 46  121.756789787374    2023/11
# 47  121.715745358781    2023/12
# 48  122.228406961957    2024/01
# 49  122.623899999559    2024/02
# 50  123.571205620535    2024/03
#
#                             Unit Indicador                               Name  \
# 0   Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 1   Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 2   Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 3   Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 4   Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 5   Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 6   Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 7   Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 8   Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 9   Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 10  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 11  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 12  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 13  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 14  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 15  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 16  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 17  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 18  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 19  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 20  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 21  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 22  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 23  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 24  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 25  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 26  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 27  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 28  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 29  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 30  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 31  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 32  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 33  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 34  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 35  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 36  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 37  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 38  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 39  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 40  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 41  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 42  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 43  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 44  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 45  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 46  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 47  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 48  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 49  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 50  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
#
#        Freq
# 0   Mensual
# 1   Mensual
# 2   Mensual
# 3   Mensual
# 4   Mensual
# 5   Mensual
# 6   Mensual
# 7   Mensual
# 8   Mensual
# 9   Mensual
# 10  Mensual
# 11  Mensual
# 12  Mensual
# 13  Mensual
# 14  Mensual
# 15  Mensual
# 16  Mensual
# 17  Mensual
# 18  Mensual
# 19  Mensual
# 20  Mensual
# 21  Mensual
# 22  Mensual
# 23  Mensual
# 24  Mensual
# 25  Mensual
# 26  Mensual
# 27  Mensual
# 28  Mensual
# 29  Mensual
# 30  Mensual
# 31  Mensual
# 32  Mensual
# 33  Mensual
# 34  Mensual
# 35  Mensual
# 36  Mensual
# 37  Mensual
# 38  Mensual
# 39  Mensual
# 40  Mensual
# 41  Mensual
# 42  Mensual
# 43  Mensual
# 44  Mensual
# 45  Mensual
# 46  Mensual
# 47  Mensual
# 48  Mensual
# 49  Mensual
# 50  Mensual

# %%
df
# Out:
#         CurrentValue TimePeriod ValueNoNumeric ValueStatus  \
# 0   99.8713989880644    2020/01
# 1   100.327453557477    2020/02
# 2   102.659576415878    2020/03
# 3   104.668949614233    2020/04
# 4   104.141031040515    2020/05
# 5   103.494822641698    2020/06
# 6   104.481839333954    2020/07
# 7   104.854011747303    2020/08
# 8   104.483432542836    2020/09
# 9   104.544548056715    2020/10
# 10  104.286063610244    2020/11
# 11  104.293330453388    2020/12
# 12  105.117889550116    2021/01
# 13  106.227089169911    2021/02
# 14  107.615671628274    2021/03
# 15  107.975562356445    2021/04
# 16  108.758794456484    2021/05
# 17   109.53367544218    2021/06
# 18  110.016963327811    2021/07
# 19  110.401996618312    2021/08
# 20  110.771040047483    2021/09
# 21  111.929447011904    2021/10
# 22  112.996538162885    2021/11
# 23  113.996785659154    2021/12
# 24  114.319491741409    2022/01
# 25  115.466391369003    2022/02
# 26  116.859841207251    2022/03
# 27  117.654293140319    2022/04
# 28  118.488796579428    2022/05
# 29  119.315341923893    2022/06
# 30   119.98965218176    2022/07
# 31  120.118906827831    2022/08
# 32  120.047471154775    2022/09
# 33  119.872171521833    2022/10
# 34  119.669616003589    2022/11
# 35  120.061750830955    2022/12
# 36  120.773962730101    2023/01
# 37  120.819125913685    2023/02
# 38  121.262395906002    2023/03
# 39  121.246624157013    2023/04
# 40  120.961546759032    2023/05
# 41  120.660241525637    2023/06
# 42  120.840632624466    2023/07
# 43  121.196044236233    2023/08
# 44  121.340790909199    2023/09
# 45  121.780187154914    2023/10
# 46  121.756789787374    2023/11
# 47  121.715745358781    2023/12
# 48  122.228406961957    2024/01
# 49  122.623899999559    2024/02
# 50  123.571205620535    2024/03
#
#                             Unit Indicador                               Name  \
# 0   Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 1   Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 2   Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 3   Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 4   Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 5   Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 6   Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 7   Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 8   Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 9   Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 10  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 11  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 12  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 13  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 14  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 15  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 16  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 17  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 18  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 19  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 20  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 21  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 22  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 23  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 24  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 25  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 26  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 27  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 28  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 29  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 30  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 31  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 32  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 33  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 34  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 35  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 36  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 37  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 38  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 39  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 40  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 41  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 42  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 43  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 44  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 45  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 46  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 47  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 48  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 49  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
# 50  Índice base julio 2019 = 100    669026  INPP sin Petróleo y con Servicios
#
#        Freq
# 0   Mensual
# 1   Mensual
# 2   Mensual
# 3   Mensual
# 4   Mensual
# 5   Mensual
# 6   Mensual
# 7   Mensual
# 8   Mensual
# 9   Mensual
# 10  Mensual
# 11  Mensual
# 12  Mensual
# 13  Mensual
# 14  Mensual
# 15  Mensual
# 16  Mensual
# 17  Mensual
# 18  Mensual
# 19  Mensual
# 20  Mensual
# 21  Mensual
# 22  Mensual
# 23  Mensual
# 24  Mensual
# 25  Mensual
# 26  Mensual
# 27  Mensual
# 28  Mensual
# 29  Mensual
# 30  Mensual
# 31  Mensual
# 32  Mensual
# 33  Mensual
# 34  Mensual
# 35  Mensual
# 36  Mensual
# 37  Mensual
# 38  Mensual
# 39  Mensual
# 40  Mensual
# 41  Mensual
# 42  Mensual
# 43  Mensual
# 44  Mensual
# 45  Mensual
# 46  Mensual
# 47  Mensual
# 48  Mensual
# 49  Mensual
# 50  Mensual

# %%
df['CurrentValue'].astype(float).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Serie A:

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


def get_table(url):
    response = requests.get(url)

    # Parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser')

    tables = soup.find_all('table', {'cellpadding': '3', 'cellspacing': '1', 'class': 'standard_tabelle'})
    table = tables[0]

    rows = table.find_all('tr')
    # Iterate over each row
    df_all = pd.DataFrame()
    for row in rows:
        df = pd.DataFrame({'date': [row.find_all('td')[0].text.strip()],
                           'time': [row.find_all('td')[1].text.strip()],
                           'team1': [row.find_all('td')[2].text.strip()],
                           'team2': [row.find_all('td')[4].text.strip()],
                           'score': [row.find_all('td')[5].text.strip()]})
        df_all = pd.concat([df_all, df])
        
    return df_all

df_all = pd.DataFrame()

n=38
for i in range(1, n+1):
    print(f"Scraping page {i} out of {n}.")
    url = f"https://www.worldfootball.net/schedule/ita-serie-a-2023-2024-spieltag/{i}/"
    df_all = pd.concat([df_all, get_table(url)])


df_all
# Out:
# Scraping page 1 out of 38.
# Scraping page 2 out of 38.
# Scraping page 3 out of 38.
# Scraping page 4 out of 38.
# Scraping page 5 out of 38.
# Scraping page 6 out of 38.
# Scraping page 7 out of 38.
# Scraping page 8 out of 38.
# Scraping page 9 out of 38.
# Scraping page 10 out of 38.
# Scraping page 11 out of 38.
# Scraping page 12 out of 38.
# Scraping page 13 out of 38.
# Scraping page 14 out of 38.
# Scraping page 15 out of 38.
# Scraping page 16 out of 38.
# Scraping page 17 out of 38.
# Scraping page 18 out of 38.
# Scraping page 19 out of 38.
# Scraping page 20 out of 38.
# Scraping page 21 out of 38.
# Scraping page 22 out of 38.
# Scraping page 23 out of 38.
# Scraping page 24 out of 38.
# Scraping page 25 out of 38.
# Scraping page 26 out of 38.
# Scraping page 27 out of 38.
# Scraping page 28 out of 38.
# Scraping page 29 out of 38.
# Scraping page 30 out of 38.
# Scraping page 31 out of 38.
# Scraping page 32 out of 38.
# Scraping page 33 out of 38.
# Scraping page 34 out of 38.
# Scraping page 35 out of 38.
# Scraping page 36 out of 38.
# Scraping page 37 out of 38.
# Scraping page 38 out of 38.
#           date   time             team1                team2      score
# 0   19/08/2023  17:30         Empoli FC        Hellas Verona  0:1 (0:0)
# 0               17:30  Frosinone Calcio           SSC Napoli  1:3 (1:2)
# 0               19:45         Genoa CFC       ACF Fiorentina  1:4 (0:3)
# 0               19:45             Inter             AC Monza  2:0 (1:0)
# 0   20/08/2023  17:30           AS Roma  US Salernitana 1919  2:2 (1:1)
# ..         ...    ...               ...                  ...        ...
# 0                         Hellas Verona                Inter        -:-
# 0                              Juventus             AC Monza        -:-
# 0                            Lazio Roma      Sassuolo Calcio        -:-
# 0                              AC Milan  US Salernitana 1919        -:-
# 0                            SSC Napoli             US Lecce        -:-
#
# [380 rows x 5 columns]

# %%
url = f"https://www.worldfootball.net/schedule/ita-serie-a-2023-2024-spieltag/{i}/"
response = requests.get(url)

soup = BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# # DANE:

# %%
url = f"https://www.dane.gov.co/index.php/estadisticas-por-tema/cuentas-nacionales/cuentas-nacionales-trimestrales/historicos-producto-interno-bruto-pib"
response = requests.get(url)

soup = BeautifulSoup(response.text, 'html.parser')
soup


tables = soup.find_all('table', {'summary': 'Periodo de referencia 2023', 'class': 'table-bordered basic-table'})
table = tables[0]
table

rows = table.find_all('tr')
rows

links = soup.find_all('a', {'class': 'descarga'})
links[3]['href']
# Out:
# '/files/operaciones/PIB/anex-GastoCorriente-IVtrim2023.xlsx'
